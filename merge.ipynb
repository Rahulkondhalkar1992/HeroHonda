# %%
dbutls.widgets.text("db", "db", "Database")
db = dbutils.widgets.get("db")

# %%
#write a merge into code
def merge_delta_into(target_table:str, source_df:DataFrame, target_match_columns:list, source_match_columns:list, target_extra_columns:list):
  for c in target_match_columns:
    assert c in target_df.columns, f"Target table is missing column {c}"
  for c in source_match_columns:
    assert c in source_df.columns, f"Source table is missing column {c}"
  for c in target_extra_columns:
    assert c in target_df.columns, f"Target table is missing column {c}"
  for c in source_match_columns:
    assert c in source_df.columns, f"Source table is missing column
